# %%
# %matplotlib inline  

import pandas
import random

import matplotlib
import numpy
import matplotlib.pyplot as plt

try:
    del df
except:
    pass

df1 = pandas.read_csv("Lab.csv")

df1['f'].plot()

# %%
df2 = pandas.DataFrame(data={
    'df1': df1['f']
         })
df2.plot.kde()

# %%
from scipy import stats
d1 = df2['df1']
print(stats.kstest(d1, 'norm', (d1.mean(), d1.std())))
# Out:
# KstestResult(statistic=0.25709862718957033, pvalue=0.34647780443921)
